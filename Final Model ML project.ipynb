# %%
import pandas as pd

# %%
df = pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.info()

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.isna()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner
# 0          False         False  False
# 1          False         False  False
# 2          False         False  False
# 3          False         False  False
# 4          False         False  False
# ..           ...           ...    ...
# 296        False         False  False
# 297        False         False  False
# 298        False         False  False
# 299        False         False  False
# 300        False         False  False
#
# [301 rows x 9 columns]

# %%
df.isnull()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner
# 0          False         False  False
# 1          False         False  False
# 2          False         False  False
# 3          False         False  False
# 4          False         False  False
# ..           ...           ...    ...
# 296        False         False  False
# 297        False         False  False
# 298        False         False  False
# 299        False         False  False
# 300        False         False  False
#
# [301 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
# # Data profilling using pandas-profilling package

# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (1.10.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (1.5.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (3.7.0)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (1.10.6)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (2.1.2)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (1.24.2)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (2.28.2)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (22.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.0)
# Requirement already satisfied: imagehash in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2022.7.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\aditi jain\appdata\local\programs\python\python311\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)

# %% [markdown]
# # EDA

# %% [markdown]
# # Check how many Numerical and catogorical columns are present

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
numeric_features
# Out:
# ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']
categorical_features
# Out:
# ['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission']

# %% [markdown]
# # Univariate Analysis(Numerical columns) using Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5, 5))
sns.kdeplot(df['Kms_Driven'],shade=True, color='b')
plt.xlabel('Kms_Driven')
plt.tight_layout()
# Out:
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\1593147355.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Kms_Driven'],shade=True, color='b')

# %%
plt.figure(figsize=(5, 5))
sns.kdeplot(df['Selling_Price'],shade=True, color='b')
plt.xlabel('Selling_Price')
plt.tight_layout()
# Out:
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\2811167913.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Selling_Price'],shade=True, color='b')

# %%
plt.figure(figsize=(5, 5))
sns.kdeplot(df['Present_Price'],shade=True, color='b')
plt.xlabel('Present_Price')
plt.tight_layout()
# Out:
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\2418088577.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Present_Price'],shade=True, color='b')

# %%
plt.figure(figsize=(5, 5))
sns.kdeplot(df['Year'],shade=True, color='b')
plt.xlabel('Year')
plt.tight_layout()
# Out:
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\3604086318.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Year'],shade=True, color='b')

# %% [markdown]
# # Univariate Analysis(Catogorical columns) using Visualization

# %%
plt.figure(figsize=(20, 15))
sns.countplot(x=df['Car_Name'])
plt.xlabel('Car_Name')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
plt.figure(figsize=(20, 15))
sns.countplot(x=df['Seller_Type'])
plt.xlabel('Seller_Type')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
plt.figure(figsize=(20, 15))
sns.countplot(x=df['Transmission'])
plt.xlabel('Transmission')
plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# # Multivariate Analysis

# %%
df[(list(df.columns)[1:])].corr()
# Out:
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\3708956574.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[(list(df.columns)[1:])].corr()
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), cmap="CMRmap", annot=True)
plt.show()
# Out:
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\1810200138.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap="CMRmap", annot=True)

# %% [markdown]
# # What is correlation

# %%
new=df[['Present_Price','Selling_Price']]
new
# Out:
#      Present_Price  Selling_Price
# 0             5.59           3.35
# 1             9.54           4.75
# 2             9.85           7.25
# 3             4.15           2.85
# 4             6.87           4.60
# ..             ...            ...
# 296          11.60           9.50
# 297           5.90           4.00
# 298          11.00           3.35
# 299          12.50          11.50
# 300           5.90           5.30
#
# [301 rows x 2 columns]

# %%
plt.figure(figsize = (15,10))
sns.heatmap(new.corr(), cmap="CMRmap", annot=True)
plt.show()

# %%
df.isnull()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner
# 0          False         False  False
# 1          False         False  False
# 2          False         False  False
# 3          False         False  False
# 4          False         False  False
# ..           ...           ...    ...
# 296        False         False  False
# 297        False         False  False
# 298        False         False  False
# 299        False         False  False
# 300        False         False  False
#
# [301 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1) Handling null Values

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
import numpy as np
df['dummyData']=''
for i in range(df.shape[0]):
    if i%2==0:
        df['dummyData'][i]=10
    else:
        df['dummyData'][i]=np.nan
# Out:
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\2005937149.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dummyData'][i]=10
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\2005937149.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dummyData'][i]=np.nan

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner dummyData
# 0        Dealer       Manual      0        10
# 1        Dealer       Manual      0       NaN
# 2        Dealer       Manual      0        10
# 3        Dealer       Manual      0       NaN
# 4        Dealer       Manual      0        10
# ..          ...          ...    ...       ...
# 296      Dealer       Manual      0        10
# 297      Dealer       Manual      0       NaN
# 298      Dealer       Manual      0        10
# 299      Dealer       Manual      0       NaN
# 300      Dealer       Manual      0        10
#
# [301 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Car_Name           0
# Year               0
# Selling_Price      0
# Present_Price      0
# Kms_Driven         0
# Fuel_Type          0
# Seller_Type        0
# Transmission       0
# Owner              0
# dummyData        150
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df.isnull().sum().dummyData
# Out:
# 150

# %%
total=df.shape[0]
total
# Out:
# 301

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'dummyData'],
#       dtype='object')

# %%
df.dummyData
# Out:
# 0       10
# 1      NaN
# 2       10
# 3      NaN
# 4       10
#       ...
# 296     10
# 297    NaN
# 298     10
# 299    NaN
# 300     10
# Name: dummyData, Length: 301, dtype: object

# %%
df=df.replace(to_replace = np.nan, value = 100)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  dummyData
# 0        Dealer       Manual      0         10
# 1        Dealer       Manual      0        100
# 2        Dealer       Manual      0         10
# 3        Dealer       Manual      0        100
# 4        Dealer       Manual      0         10
# ..          ...          ...    ...        ...
# 296      Dealer       Manual      0         10
# 297      Dealer       Manual      0        100
# 298      Dealer       Manual      0         10
# 299      Dealer       Manual      0        100
# 300      Dealer       Manual      0         10
#
# [301 rows x 10 columns]

# %%
# filling missing value using fillna()  
#df.fillna(0)
#df.fillna(method ='pad')
#df.fillna(method ='bfill')


#df.replace(to_replace = np.nan, value = -99) 

#df.interpolate(method ='linear', limit_direction ='forward')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  dummyData
# 0        Dealer       Manual      0         10
# 1        Dealer       Manual      0        100
# 2        Dealer       Manual      0         10
# 3        Dealer       Manual      0        100
# 4        Dealer       Manual      0         10
# ..          ...          ...    ...        ...
# 296      Dealer       Manual      0         10
# 297      Dealer       Manual      0        100
# 298      Dealer       Manual      0         10
# 299      Dealer       Manual      0        100
# 300      Dealer       Manual      0         10
#
# [301 rows x 10 columns]

# %% [markdown]
# ## 2) one hot encoding

# %%
categorical_features
# Out:
# ['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission']

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  dummyData
# 0        Dealer       Manual      0         10
# 1        Dealer       Manual      0        100
# 2        Dealer       Manual      0         10
# 3        Dealer       Manual      0        100
# 4        Dealer       Manual      0         10
# ..          ...          ...    ...        ...
# 296      Dealer       Manual      0         10
# 297      Dealer       Manual      0        100
# 298      Dealer       Manual      0         10
# 299      Dealer       Manual      0        100
# 300      Dealer       Manual      0         10
#
# [301 rows x 10 columns]

# %%
df['Transmission']
# Out:
# 0      Manual
# 1      Manual
# 2      Manual
# 3      Manual
# 4      Manual
#         ...
# 296    Manual
# 297    Manual
# 298    Manual
# 299    Manual
# 300    Manual
# Name: Transmission, Length: 301, dtype: object

# %%
df['Transmission'].value_counts()
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
df['Fuel_Type']
# Out:
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
#         ...
# 296    Diesel
# 297    Petrol
# 298    Petrol
# 299    Diesel
# 300    Petrol
# Name: Fuel_Type, Length: 301, dtype: object

# %% [markdown]
# ## 3) Handle Outlier

# %%
numeric_features
# Out:
# ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
import seaborn as sns
sns.boxplot(x=df['Year'])
# Out:
# <Axes: xlabel='Year'>

# %%
import seaborn as sns
sns.boxplot(x=df['Selling_Price'])
# Out:
# <Axes: xlabel='Selling_Price'>

# %%
import seaborn as sns
sns.boxplot(x=df['Present_Price'])
# Out:
# <Axes: xlabel='Present_Price'>

# %%
import seaborn as sns
sns.boxplot(x=df['Kms_Driven'])
# Out:
# <Axes: xlabel='Kms_Driven'>

# %%
import seaborn as sns
sns.boxplot(x=df['Owner'])
# Out:
# <Axes: xlabel='Owner'>

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Selling_Price'], df['Selling_Price'])

# %% [markdown]
# # Model Building

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  dummyData
# 0      Dealer       Manual      0         10
# 1      Dealer       Manual      0        100
# 2      Dealer       Manual      0         10
# 3      Dealer       Manual      0        100
# 4      Dealer       Manual      0         10

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'dummyData'],
#       dtype='object')

# %%
df1=df[['Year', 'Present_Price', 'Kms_Driven','Fuel_Type']]
df2=df['Selling_Price']

# %%
# df1 = pd.get_dummies(df1,drop_first = True)
df1['Fuel_Type'] = df1['Fuel_Type'].map({"Petrol":1, "Diesel":2, "CNG":3})
# Out:
# C:\Users\Aditi Jain\AppData\Local\Temp\ipykernel_3560\1399634706.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Fuel_Type'] = df1['Fuel_Type'].map({"Petrol":1, "Diesel":2, "CNG":3})

# %%
df1.head()
# Out:
#    Year  Present_Price  Kms_Driven  Fuel_Type
# 0  2014           5.59       27000          1
# 1  2013           9.54       43000          2
# 2  2017           9.85        6900          1
# 3  2011           4.15        5200          1
# 4  2014           6.87       42450          2

# %%
df1.isnull().sum()
# Out:
# Year             0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# dtype: int64

# %%
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X= df1.to_numpy()
y= df2.to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
regr = LinearRegression()
 
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(X)
# Out:
# [[2.0140e+03 5.5900e+00 2.7000e+04 1.0000e+00]
#  [2.0130e+03 9.5400e+00 4.3000e+04 2.0000e+00]
#  [2.0170e+03 9.8500e+00 6.9000e+03 1.0000e+00]
#  ...
#  [2.0090e+03 1.1000e+01 8.7934e+04 1.0000e+00]
#  [2.0170e+03 1.2500e+01 9.0000e+03 2.0000e+00]
#  [2.0160e+03 5.9000e+00 5.4640e+03 1.0000e+00]]

# %%
type(regr)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
y_pred = regr.predict(X_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
r2 = r2_score(y_test,y_pred)
print(f"R2 score: {r2:.2f}")
# Out:
# R2 score: 0.81

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 3.17

# %%
plt.scatter(y_test,y_pred)

# %%
# import pickle
# # file where you want to store data
# file = open('regression.pkl','wb')

# # dump information to that file
# pickle.dump()

# %%
import pickle
pickle_out = open("regression.pkl","wb")
pickle.dump(regr, pickle_out)
pickle_out.close()
